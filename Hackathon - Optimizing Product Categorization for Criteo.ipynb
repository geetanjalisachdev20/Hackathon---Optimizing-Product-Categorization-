# %%
import copy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
import tqdm
from scipy import stats
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from sklearn.decomposition import PCA
from sklearn.model_selection import StratifiedShuffleSplit

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
BASE_DIR = '/content/drive/MyDrive/Criteo_Hackathon'
os.chdir(BASE_DIR)

# %% [markdown]
# ###SAMPLING THE BULK DATASET

# %%
bulk_data = np.load("bulk_embeddings.npy")

labels = bulk_data[:, -1]

# Count the occurrences of each label
unique_labels, label_counts = np.unique(labels, return_counts=True)

# Print the counts for each label
for label, count in zip(unique_labels, label_counts):
    print("Label {}: {} occurrences".format(label, count))
# Out:
# Label 0.0: 95 occurrences
# Label 1.0: 193 occurrences
# Label 2.0: 51 occurrences
# Label 3.0: 65 occurrences
# Label 4.0: 27 occurrences
# Label 5.0: 39 occurrences
# Label 6.0: 1 occurrences
# Label 7.0: 532 occurrences
# Label 8.0: 60 occurrences
# Label 9.0: 1251 occurrences
# Label 10.0: 308 occurrences
# Label 11.0: 44 occurrences
# Label 12.0: 332 occurrences
# Label 13.0: 110 occurrences
# Label 14.0: 19 occurrences
# Label 15.0: 11 occurrences
# Label 16.0: 1 occurrences
# Label 17.0: 1 occurrences
# Label 18.0: 1259 occurrences
# Label 19.0: 621 occurrences
# Label 20.0: 498 occurrences
# Label 21.0: 1037 occurrences
# Label 22.0: 416 occurrences
# Label 23.0: 61 occurrences
# Label 24.0: 156 occurrences
# Label 25.0: 6 occurrences
# Label 26.0: 117 occurrences
# Label 28.0: 48 occurrences
# Label 29.0: 377 occurrences
# Label 30.0: 583 occurrences
# Label 31.0: 242 occurrences
# Label 32.0: 46 occurrences
# Label 33.0: 33 occurrences
# Label 34.0: 209 occurrences
# Label 35.0: 234 occurrences
# Label 36.0: 125 occurrences
# Label 37.0: 20 occurrences
# Label 38.0: 1 occurrences
# Label 40.0: 61 occurrences
# Label 41.0: 20 occurrences
# Label 42.0: 2 occurrences
# Label 44.0: 19 occurrences
# Label 45.0: 46 occurrences
# Label 46.0: 310 occurrences
# Label 47.0: 61 occurrences
# Label 48.0: 64 occurrences
# Label 49.0: 6 occurrences
# Label 50.0: 93 occurrences
# Label 51.0: 40 occurrences
# Label 52.0: 105 occurrences
# Label 53.0: 63 occurrences
# Label 54.0: 191 occurrences
# Label 55.0: 16 occurrences
# Label 56.0: 171 occurrences
# Label 57.0: 158 occurrences
# Label 58.0: 87 occurrences
# Label 59.0: 73 occurrences
# Label 60.0: 230 occurrences
# Label 61.0: 111 occurrences
# Label 62.0: 7 occurrences
# Label 63.0: 55 occurrences
# Label 64.0: 20 occurrences
# Label 65.0: 193 occurrences
# Label 66.0: 482 occurrences
# Label 67.0: 1504 occurrences
# Label 68.0: 242 occurrences
# Label 69.0: 556 occurrences
# Label 70.0: 56 occurrences
# Label 71.0: 40 occurrences
# Label 72.0: 498 occurrences
# Label 73.0: 129 occurrences
# Label 74.0: 169 occurrences
# Label 75.0: 342 occurrences
# Label 77.0: 25 occurrences
# Label 78.0: 1 occurrences
# Label 79.0: 11 occurrences
# Label 80.0: 30 occurrences
# Label 82.0: 14 occurrences
# Label 83.0: 44 occurrences
# Label 1002.0: 100 occurrences
# Label 1003.0: 50 occurrences
# Label 1006.0: 3 occurrences
# Label 1010.0: 1 occurrences
# Label 1011.0: 5 occurrences
# Label 1012.0: 9 occurrences
# Label 1013.0: 30 occurrences
# Label 1015.0: 14 occurrences
# Label 1019.0: 163 occurrences
# Label 1020.0: 53 occurrences
# Label 1021.0: 4 occurrences
# Label 1022.0: 2 occurrences
# Label 1023.0: 1 occurrences
# Label 1026.0: 6814 occurrences
# Label 1027.0: 6 occurrences
# Label 1028.0: 23 occurrences
# Label 1029.0: 55 occurrences
# Label 1030.0: 24 occurrences
# Label 1031.0: 240 occurrences
# Label 1032.0: 106 occurrences
# Label 1033.0: 188 occurrences
# Label 1034.0: 169 occurrences
# Label 1035.0: 3017 occurrences
# Label 1036.0: 237 occurrences
# Label 1037.0: 12 occurrences
# Label 1038.0: 210 occurrences
# Label 1039.0: 2289 occurrences
# Label 1040.0: 604 occurrences
# Label 1041.0: 55 occurrences
# Label 1042.0: 192 occurrences
# Label 1043.0: 15 occurrences
# Label 1044.0: 15 occurrences
# Label 1045.0: 254 occurrences
# Label 1046.0: 913 occurrences
# Label 1047.0: 890 occurrences
# Label 1048.0: 4048 occurrences
# Label 1049.0: 1974 occurrences
# Label 1050.0: 786 occurrences
# Label 1051.0: 222 occurrences
# Label 1052.0: 365 occurrences
# Label 1053.0: 159 occurrences
# Label 1054.0: 339 occurrences
# Label 1055.0: 504 occurrences
# Label 1056.0: 30 occurrences
# Label 1057.0: 20 occurrences
# Label 1058.0: 15 occurrences
# Label 1059.0: 268 occurrences
# Label 1060.0: 89 occurrences
# Label 1061.0: 634 occurrences
# Label 1062.0: 1055 occurrences
# Label 1063.0: 732 occurrences
# Label 1064.0: 95 occurrences
# Label 1065.0: 94 occurrences
# Label 1066.0: 547 occurrences
# Label 1067.0: 233 occurrences
# Label 1068.0: 44 occurrences
# Label 1069.0: 50 occurrences
# Label 1070.0: 10 occurrences
# Label 1071.0: 29 occurrences
# Label 1072.0: 521 occurrences
# Label 1073.0: 1271 occurrences
# Label 1074.0: 884 occurrences
# Label 1075.0: 340 occurrences
# Label 1076.0: 1925 occurrences
# Label 1077.0: 398 occurrences
# Label 1078.0: 524 occurrences
# Label 1079.0: 941 occurrences
# Label 1080.0: 2500 occurrences
# Label 1081.0: 239 occurrences
# Label 1082.0: 1496 occurrences
# Label 1083.0: 161 occurrences
# Label 1084.0: 103 occurrences
# Label 1085.0: 177 occurrences
# Label 1086.0: 1531 occurrences
# Label 1087.0: 177 occurrences
# Label 1088.0: 196 occurrences
# Label 1089.0: 302 occurrences
# Label 1090.0: 339 occurrences
# Label 1091.0: 18 occurrences
# Label 1092.0: 1340 occurrences
# Label 1093.0: 1306 occurrences
# Label 1094.0: 82 occurrences
# Label 1095.0: 205 occurrences
# Label 1096.0: 170 occurrences
# Label 1097.0: 82 occurrences
# Label 1098.0: 1028 occurrences
# Label 1099.0: 42 occurrences
# Label 1100.0: 376 occurrences
# Label 1101.0: 1802 occurrences
# Label 1102.0: 5 occurrences
# Label 1103.0: 6 occurrences
# Label 1104.0: 209 occurrences
# Label 1105.0: 2346 occurrences
# Label 1106.0: 921 occurrences
# Label 1107.0: 227 occurrences
# Label 1108.0: 835 occurrences
# Label 1109.0: 8868 occurrences
# Label 1110.0: 1046 occurrences
# Label 1111.0: 3255 occurrences
# Label 1112.0: 8143 occurrences
# Label 1113.0: 46 occurrences
# Label 1114.0: 126 occurrences
# Label 1115.0: 196 occurrences
# Label 1116.0: 21 occurrences
# Label 1117.0: 332 occurrences
# Label 1118.0: 29 occurrences
# Label 1119.0: 65 occurrences
# Label 1121.0: 47 occurrences
# Label 1122.0: 8 occurrences
# Label 1123.0: 9 occurrences
# Label 1124.0: 293 occurrences
# Label 1125.0: 324 occurrences
# Label 1126.0: 10 occurrences
# Label 1128.0: 471 occurrences
# Label 1129.0: 257 occurrences
# Label 1130.0: 105 occurrences
# Label 1131.0: 58 occurrences
# Label 1133.0: 86 occurrences
# Label 1134.0: 564 occurrences
# Label 1135.0: 15 occurrences
# Label 1136.0: 579 occurrences
# Label 1137.0: 139 occurrences
# Label 1138.0: 254 occurrences
# Label 1139.0: 64 occurrences
# Label 1140.0: 71 occurrences
# Label 1141.0: 21 occurrences
# Label 1142.0: 373 occurrences
# Label 1143.0: 1247 occurrences
# Label 1144.0: 436 occurrences
# Label 1145.0: 124 occurrences
# Label 1146.0: 453 occurrences
# Label 1147.0: 112 occurrences
# Label 1148.0: 55 occurrences
# Label 1149.0: 701 occurrences
# Label 1150.0: 174 occurrences
# Label 1151.0: 5221 occurrences
# Label 1152.0: 201 occurrences
# Label 1153.0: 500 occurrences
# Label 1154.0: 25 occurrences
# Label 1155.0: 30 occurrences
# Label 1157.0: 225 occurrences
# Label 1158.0: 127 occurrences
# Label 1159.0: 1 occurrences
# Label 1160.0: 20 occurrences
# Label 1162.0: 23 occurrences
# Label 1163.0: 102 occurrences
# Label 1164.0: 24 occurrences
# Label 1165.0: 4 occurrences
# Label 1166.0: 1 occurrences
# Label 1167.0: 32 occurrences
# Label 1168.0: 1 occurrences
# Label 1170.0: 66 occurrences
# Label 1173.0: 4 occurrences
# Label 1174.0: 59 occurrences
# Label 1177.0: 21 occurrences
# Label 1178.0: 1 occurrences
# Label 1180.0: 12 occurrences
# Label 1181.0: 16 occurrences
# Label 1182.0: 1 occurrences
# Label 1188.0: 31 occurrences
# Label 1189.0: 3429 occurrences
# Label 1190.0: 218 occurrences
# Label 1191.0: 20169 occurrences
# Label 1192.0: 9601 occurrences
# Label 1193.0: 9506 occurrences
# Label 1194.0: 14647 occurrences
# Label 1195.0: 12547 occurrences
# Label 1196.0: 140 occurrences
# Label 1197.0: 5 occurrences
# Label 1198.0: 520 occurrences
# Label 1199.0: 213 occurrences
# Label 1200.0: 39 occurrences
# Label 1201.0: 106 occurrences
# Label 1202.0: 14 occurrences
# Label 1203.0: 11 occurrences
# Label 1204.0: 1205 occurrences
# Label 1205.0: 4471 occurrences
# Label 1206.0: 1183 occurrences
# Label 1207.0: 46 occurrences
# Label 1208.0: 102 occurrences
# Label 1209.0: 30 occurrences
# Label 1210.0: 102 occurrences
# Label 1211.0: 3378 occurrences
# Label 1212.0: 78 occurrences
# Label 1213.0: 11 occurrences
# Label 1214.0: 25 occurrences
# Label 1215.0: 2 occurrences
# Label 1216.0: 110 occurrences
# Label 1217.0: 75 occurrences
# Label 1218.0: 125 occurrences
# Label 1219.0: 5 occurrences
# Label 1220.0: 5 occurrences
# Label 1223.0: 12 occurrences
# Label 1224.0: 11 occurrences
# Label 1225.0: 6 occurrences
# Label 1226.0: 344 occurrences
# Label 1227.0: 38 occurrences
# Label 1228.0: 44 occurrences
# Label 1229.0: 3 occurrences
# Label 1230.0: 5 occurrences
# Label 1231.0: 978 occurrences
# Label 1232.0: 391 occurrences
# Label 1233.0: 2 occurrences
# Label 1234.0: 38 occurrences
# Label 1235.0: 1 occurrences
# Label 1236.0: 67 occurrences
# Label 1237.0: 69 occurrences
# Label 1238.0: 17 occurrences
# Label 1239.0: 186 occurrences
# Label 1240.0: 27 occurrences
# Label 1241.0: 20 occurrences
# Label 1242.0: 35 occurrences
# Label 1243.0: 12 occurrences
# Label 1244.0: 13 occurrences
# Label 1245.0: 15 occurrences
# Label 1246.0: 6 occurrences
# Label 1247.0: 3 occurrences
# Label 1248.0: 32 occurrences
# Label 1250.0: 1 occurrences
# Label 1251.0: 212 occurrences
# Label 1252.0: 51 occurrences
# Label 1253.0: 488 occurrences
# Label 1254.0: 377 occurrences
# Label 1255.0: 301 occurrences
# Label 1257.0: 39 occurrences
# Label 1258.0: 60 occurrences
# Label 1259.0: 1050 occurrences
# Label 1260.0: 29 occurrences
# Label 1261.0: 35 occurrences
# Label 1262.0: 9 occurrences
# Label 1264.0: 481 occurrences
# Label 1265.0: 9990 occurrences
# Label 1266.0: 132 occurrences
# Label 1267.0: 14 occurrences
# Label 1268.0: 60 occurrences
# Label 1269.0: 764 occurrences
# Label 1270.0: 682 occurrences
# Label 1271.0: 280 occurrences
# Label 1272.0: 80 occurrences
# Label 1273.0: 132 occurrences
# Label 1274.0: 11 occurrences
# Label 1275.0: 147 occurrences
# Label 1276.0: 184 occurrences
# Label 1277.0: 41 occurrences
# Label 1278.0: 24 occurrences
# Label 1279.0: 602 occurrences
# Label 1280.0: 32 occurrences
# Label 1281.0: 37 occurrences
# Label 1282.0: 135 occurrences
# Label 1283.0: 1 occurrences
# Label 1285.0: 11 occurrences
# Label 1286.0: 1 occurrences
# Label 1288.0: 9 occurrences
# Label 1289.0: 23 occurrences
# Label 1290.0: 1702 occurrences
# Label 1292.0: 1 occurrences
# Label 1293.0: 1 occurrences
# Label 1294.0: 21 occurrences
# Label 1295.0: 1447 occurrences
# Label 1296.0: 131 occurrences
# Label 1297.0: 42 occurrences
# Label 1298.0: 701 occurrences
# Label 1299.0: 981 occurrences
# Label 1300.0: 60 occurrences
# Label 1302.0: 1 occurrences
# Label 1303.0: 404 occurrences
# Label 1304.0: 1281 occurrences
# Label 1305.0: 89 occurrences
# Label 1306.0: 88 occurrences
# Label 1307.0: 2077 occurrences
# Label 1308.0: 235 occurrences
# Label 1309.0: 434 occurrences
# Label 1310.0: 217 occurrences
# Label 1311.0: 222 occurrences
# Label 1312.0: 1082 occurrences
# Label 1313.0: 119 occurrences
# Label 1314.0: 173 occurrences
# Label 1315.0: 413 occurrences
# Label 1316.0: 446 occurrences
# Label 1317.0: 595 occurrences
# Label 1318.0: 78 occurrences
# Label 1319.0: 764 occurrences
# Label 1320.0: 92 occurrences
# Label 1321.0: 1 occurrences
# Label 1322.0: 1 occurrences
# Label 1323.0: 27 occurrences
# Label 1324.0: 59 occurrences
# Label 1325.0: 326 occurrences
# Label 1326.0: 141 occurrences
# Label 1327.0: 296 occurrences
# Label 1328.0: 311 occurrences
# Label 1329.0: 236 occurrences
# Label 1330.0: 695 occurrences
# Label 1331.0: 891 occurrences
# Label 1332.0: 6592 occurrences
# Label 1333.0: 6440 occurrences
# Label 1334.0: 183 occurrences
# Label 1335.0: 3221 occurrences
# Label 1336.0: 5561 occurrences
# Label 1337.0: 248 occurrences
# Label 1338.0: 81 occurrences
# Label 1339.0: 34 occurrences
# Label 1340.0: 7 occurrences
# Label 1341.0: 506 occurrences
# Label 1342.0: 1015 occurrences
# Label 1343.0: 44 occurrences
# Label 1344.0: 2293 occurrences
# Label 1345.0: 140 occurrences
# Label 1346.0: 34 occurrences
# Label 1347.0: 10 occurrences
# Label 1349.0: 11 occurrences
# Label 1352.0: 39 occurrences
# Label 1353.0: 108 occurrences
# Label 1354.0: 1653 occurrences
# Label 1355.0: 766 occurrences
# Label 1356.0: 1581 occurrences
# Label 1357.0: 475 occurrences
# Label 1358.0: 123 occurrences
# Label 1359.0: 2392 occurrences
# Label 1360.0: 570 occurrences
# Label 1361.0: 733 occurrences
# Label 1362.0: 3925 occurrences
# Label 1363.0: 203 occurrences
# Label 1364.0: 1410 occurrences
# Label 1365.0: 1 occurrences
# Label 1366.0: 70 occurrences
# Label 1367.0: 11 occurrences
# Label 1368.0: 1219 occurrences
# Label 1369.0: 299 occurrences
# Label 1370.0: 35 occurrences
# Label 1371.0: 139 occurrences
# Label 1372.0: 644 occurrences
# Label 1373.0: 3 occurrences
# Label 1375.0: 11 occurrences
# Label 1376.0: 36 occurrences
# Label 1377.0: 47 occurrences
# Label 1379.0: 5 occurrences
# Label 1380.0: 89 occurrences
# Label 1381.0: 79 occurrences
# Label 1382.0: 184 occurrences
# Label 1383.0: 158 occurrences
# Label 1384.0: 292 occurrences
# Label 1385.0: 54 occurrences
# Label 1386.0: 145 occurrences
# Label 1387.0: 79 occurrences
# Label 1388.0: 20 occurrences
# Label 1389.0: 2183 occurrences
# Label 1390.0: 192 occurrences
# Label 1391.0: 22 occurrences
# Label 1392.0: 114 occurrences
# Label 1393.0: 10 occurrences
# Label 1394.0: 170 occurrences
# Label 1395.0: 50 occurrences
# Label 1396.0: 16 occurrences
# Label 1398.0: 139 occurrences
# Label 1399.0: 852 occurrences
# Label 1400.0: 519 occurrences
# Label 1401.0: 606 occurrences
# Label 1402.0: 178 occurrences
# Label 1403.0: 63 occurrences
# Label 1404.0: 63 occurrences
# Label 1405.0: 86 occurrences
# Label 1406.0: 66 occurrences
# Label 1407.0: 18 occurrences
# Label 1408.0: 97 occurrences
# Label 1409.0: 59 occurrences
# Label 1410.0: 18 occurrences
# Label 1411.0: 19 occurrences
# Label 1412.0: 9 occurrences
# Label 1414.0: 4 occurrences
# Label 1415.0: 1 occurrences
# Label 1416.0: 1 occurrences
# Label 1417.0: 2 occurrences
# Label 1418.0: 16 occurrences
# Label 1419.0: 41 occurrences
# Label 1420.0: 38 occurrences
# Label 1421.0: 28 occurrences
# Label 1422.0: 12 occurrences
# Label 1423.0: 9 occurrences
# Label 1424.0: 21 occurrences
# Label 1425.0: 9 occurrences
# Label 1427.0: 5 occurrences
# Label 1428.0: 10 occurrences
# Label 1429.0: 603 occurrences
# Label 1430.0: 119 occurrences
# Label 1431.0: 1257 occurrences
# Label 1432.0: 31 occurrences
# Label 1433.0: 2277 occurrences
# Label 1434.0: 798 occurrences
# Label 1435.0: 187 occurrences
# Label 1436.0: 128 occurrences
# Label 1437.0: 96 occurrences
# Label 1438.0: 206 occurrences
# Label 1439.0: 444 occurrences
# Label 1440.0: 185 occurrences
# Label 1441.0: 10 occurrences
# Label 1442.0: 347 occurrences
# Label 1443.0: 147 occurrences
# Label 1444.0: 242 occurrences
# Label 1445.0: 250 occurrences
# Label 1446.0: 164 occurrences
# Label 1447.0: 133 occurrences
# Label 1448.0: 151 occurrences
# Label 1449.0: 1838 occurrences
# Label 1450.0: 44 occurrences
# Label 1451.0: 40 occurrences
# Label 1452.0: 40 occurrences
# Label 1453.0: 9 occurrences
# Label 1454.0: 133 occurrences
# Label 1459.0: 262 occurrences
# Label 1460.0: 117 occurrences
# Label 1461.0: 29 occurrences
# Label 1462.0: 7 occurrences
# Label 1463.0: 17 occurrences
# Label 1464.0: 181 occurrences
# Label 1465.0: 239 occurrences
# Label 1466.0: 278 occurrences
# Label 1467.0: 48 occurrences
# Label 1468.0: 6063 occurrences
# Label 1469.0: 109 occurrences
# Label 1470.0: 214 occurrences
# Label 1471.0: 59 occurrences
# Label 1472.0: 128 occurrences
# Label 1473.0: 129 occurrences
# Label 1476.0: 3 occurrences
# Label 1477.0: 43 occurrences
# Label 1478.0: 443 occurrences
# Label 1479.0: 1 occurrences
# Label 1480.0: 212 occurrences
# Label 1481.0: 609 occurrences
# Label 1482.0: 289 occurrences
# Label 1483.0: 1256 occurrences
# Label 1484.0: 566 occurrences
# Label 1485.0: 311 occurrences
# Label 1486.0: 84 occurrences
# Label 1487.0: 7 occurrences
# Label 1488.0: 1436 occurrences
# Label 1489.0: 262 occurrences
# Label 1490.0: 414 occurrences
# Label 1491.0: 125 occurrences
# Label 1492.0: 315 occurrences
# Label 1493.0: 98 occurrences
# Label 1494.0: 66 occurrences
# Label 1495.0: 54 occurrences
# Label 1496.0: 261 occurrences
# Label 1497.0: 75 occurrences
# Label 1498.0: 1 occurrences
# Label 1499.0: 11 occurrences
# Label 1500.0: 36 occurrences
# Label 1501.0: 28 occurrences
# Label 1502.0: 59 occurrences
# Label 1503.0: 84 occurrences
# Label 1504.0: 184 occurrences
# Label 1505.0: 270 occurrences
# Label 1506.0: 163 occurrences
# Label 1507.0: 68 occurrences
# Label 1508.0: 207 occurrences
# Label 1509.0: 74 occurrences
# Label 1510.0: 48 occurrences
# Label 1511.0: 11 occurrences
# Label 1512.0: 378 occurrences
# Label 1513.0: 66 occurrences
# Label 1514.0: 29 occurrences
# Label 1515.0: 92 occurrences
# Label 1516.0: 4 occurrences
# Label 1517.0: 6 occurrences
# Label 1518.0: 65 occurrences
# Label 1519.0: 145 occurrences
# Label 1520.0: 138 occurrences
# Label 1521.0: 432 occurrences
# Label 1523.0: 12 occurrences
# Label 1524.0: 433 occurrences
# Label 1525.0: 61 occurrences
# Label 1526.0: 275 occurrences
# Label 1527.0: 3 occurrences
# Label 1528.0: 171 occurrences
# Label 1530.0: 19 occurrences
# Label 1531.0: 159 occurrences
# Label 1532.0: 8 occurrences
# Label 1533.0: 89 occurrences
# Label 1534.0: 52 occurrences
# Label 1535.0: 40 occurrences
# Label 1536.0: 7 occurrences
# Label 1537.0: 56 occurrences
# Label 1538.0: 39 occurrences
# Label 1541.0: 1 occurrences
# Label 1542.0: 40 occurrences
# Label 1543.0: 126 occurrences
# Label 1544.0: 16 occurrences
# Label 1545.0: 22 occurrences
# Label 1546.0: 8 occurrences
# Label 1547.0: 9 occurrences
# Label 1548.0: 25 occurrences
# Label 1549.0: 185 occurrences
# Label 1553.0: 2 occurrences
# Label 1555.0: 2563 occurrences
# Label 1556.0: 10 occurrences
# Label 1557.0: 16 occurrences
# Label 1558.0: 278 occurrences
# Label 1559.0: 10415 occurrences
# Label 1560.0: 12624 occurrences
# Label 1561.0: 2036 occurrences
# Label 1562.0: 324 occurrences
# Label 1563.0: 164 occurrences
# Label 1564.0: 3097 occurrences
# Label 1565.0: 230 occurrences
# Label 1566.0: 215 occurrences
# Label 1567.0: 1 occurrences
# Label 1568.0: 46 occurrences
# Label 1569.0: 891 occurrences
# Label 1570.0: 779 occurrences
# Label 1571.0: 731 occurrences
# Label 1572.0: 871 occurrences
# Label 1573.0: 1471 occurrences
# Label 1574.0: 1080 occurrences
# Label 1575.0: 3923 occurrences
# Label 1576.0: 13 occurrences
# Label 1577.0: 1 occurrences
# Label 1578.0: 36 occurrences
# Label 1579.0: 867 occurrences
# Label 1580.0: 232 occurrences
# Label 1581.0: 78 occurrences
# Label 1582.0: 205 occurrences
# Label 1583.0: 146 occurrences
# Label 1584.0: 84 occurrences
# Label 1585.0: 50 occurrences
# Label 1586.0: 530 occurrences
# Label 1587.0: 638 occurrences
# Label 1588.0: 150 occurrences
# Label 1589.0: 983 occurrences
# Label 1590.0: 10 occurrences
# Label 1591.0: 88 occurrences
# Label 1592.0: 160 occurrences
# Label 1593.0: 234 occurrences
# Label 1594.0: 44 occurrences
# Label 1595.0: 111 occurrences
# Label 1596.0: 317 occurrences
# Label 1597.0: 61 occurrences
# Label 1598.0: 124 occurrences
# Label 1599.0: 9 occurrences
# Label 1600.0: 32 occurrences
# Label 1601.0: 120 occurrences
# Label 1602.0: 29 occurrences
# Label 1604.0: 52 occurrences
# Label 1605.0: 17 occurrences
# Label 1606.0: 952 occurrences
# Label 1607.0: 347 occurrences
# Label 1608.0: 17 occurrences
# Label 1609.0: 43 occurrences
# Label 1610.0: 21 occurrences
# Label 1611.0: 311 occurrences
# Label 1612.0: 71 occurrences
# Label 1613.0: 17 occurrences
# Label 1614.0: 1115 occurrences
# Label 1615.0: 14 occurrences
# Label 1616.0: 134 occurrences
# Label 1617.0: 3 occurrences
# Label 1618.0: 247 occurrences
# Label 1619.0: 2743 occurrences
# Label 1620.0: 1197 occurrences
# Label 1621.0: 85 occurrences
# Label 1622.0: 404 occurrences
# Label 1623.0: 52 occurrences
# Label 1624.0: 218 occurrences
# Label 1625.0: 11 occurrences
# Label 1626.0: 26 occurrences
# Label 1627.0: 50 occurrences
# Label 1628.0: 64 occurrences
# Label 1629.0: 2 occurrences
# Label 1630.0: 198 occurrences
# Label 1632.0: 12 occurrences
# Label 1633.0: 1158 occurrences
# Label 1634.0: 7011 occurrences
# Label 1635.0: 77 occurrences
# Label 1636.0: 198 occurrences
# Label 1637.0: 8 occurrences
# Label 1640.0: 38 occurrences
# Label 1642.0: 16 occurrences
# Label 1643.0: 2 occurrences
# Label 1644.0: 3 occurrences
# Label 1645.0: 52 occurrences
# Label 1647.0: 8 occurrences
# Label 1648.0: 2 occurrences
# Label 1649.0: 1 occurrences
# Label 1651.0: 1 occurrences
# Label 1652.0: 1659 occurrences
# Label 1654.0: 41 occurrences
# Label 1655.0: 25 occurrences
# Label 1656.0: 3 occurrences
# Label 1657.0: 815 occurrences
# Label 1658.0: 25 occurrences
# Label 1660.0: 226 occurrences
# Label 1661.0: 1296 occurrences
# Label 1662.0: 181 occurrences
# Label 1663.0: 337 occurrences
# Label 1664.0: 225 occurrences
# Label 1665.0: 120 occurrences
# Label 1666.0: 81 occurrences
# Label 1667.0: 468 occurrences
# Label 1668.0: 534 occurrences
# Label 1669.0: 74 occurrences
# Label 1670.0: 212 occurrences
# Label 1671.0: 60 occurrences
# Label 1672.0: 150 occurrences
# Label 1673.0: 2899 occurrences
# Label 1674.0: 3559 occurrences
# Label 1675.0: 268 occurrences
# Label 1676.0: 193 occurrences
# Label 1677.0: 35 occurrences
# Label 1678.0: 134 occurrences
# Label 1679.0: 4 occurrences
# Label 1680.0: 1 occurrences
# Label 1681.0: 2 occurrences
# Label 1682.0: 67 occurrences
# Label 1683.0: 331 occurrences
# Label 1684.0: 89 occurrences
# Label 1685.0: 380 occurrences
# Label 1686.0: 1012 occurrences
# Label 1687.0: 95 occurrences
# Label 1688.0: 23 occurrences
# Label 1689.0: 84 occurrences
# Label 1690.0: 438 occurrences
# Label 1691.0: 2 occurrences
# Label 1692.0: 1 occurrences
# Label 1693.0: 404 occurrences
# Label 1694.0: 68 occurrences
# Label 1695.0: 375 occurrences
# Label 1696.0: 1118 occurrences
# Label 1697.0: 917 occurrences
# Label 1698.0: 23 occurrences
# Label 1699.0: 74 occurrences
# Label 1700.0: 2155 occurrences
# Label 1701.0: 8 occurrences
# Label 1702.0: 131 occurrences
# Label 1703.0: 57 occurrences
# Label 1704.0: 4 occurrences
# Label 1705.0: 612 occurrences
# Label 1706.0: 99 occurrences
# Label 1707.0: 109 occurrences
# Label 1708.0: 74 occurrences
# Label 1709.0: 42 occurrences
# Label 1710.0: 68 occurrences
# Label 1711.0: 131 occurrences
# Label 1712.0: 22 occurrences
# Label 1713.0: 84 occurrences
# Label 1714.0: 31 occurrences
# Label 1715.0: 71 occurrences
# Label 1716.0: 224 occurrences
# Label 1717.0: 17 occurrences
# Label 1718.0: 49 occurrences
# Label 1719.0: 738 occurrences
# Label 1720.0: 144 occurrences
# Label 1721.0: 210 occurrences
# Label 1722.0: 137 occurrences
# Label 1723.0: 17 occurrences
# Label 1724.0: 24 occurrences
# Label 1725.0: 215 occurrences
# Label 1726.0: 127 occurrences
# Label 1727.0: 121 occurrences
# Label 1728.0: 39 occurrences
# Label 1729.0: 2 occurrences
# Label 1730.0: 2 occurrences
# Label 1732.0: 50 occurrences
# Label 1733.0: 12 occurrences
# Label 1734.0: 30 occurrences
# Label 1735.0: 142 occurrences
# Label 1736.0: 87 occurrences
# Label 1737.0: 52 occurrences
# Label 1738.0: 129 occurrences
# Label 1740.0: 12 occurrences
# Label 1741.0: 1 occurrences
# Label 1742.0: 1 occurrences
# Label 1743.0: 7 occurrences
# Label 1744.0: 88 occurrences
# Label 1745.0: 25 occurrences
# Label 1746.0: 34 occurrences
# Label 1747.0: 1667 occurrences
# Label 1748.0: 360451 occurrences
# Label 1749.0: 252 occurrences
# Label 1750.0: 32 occurrences
# Label 1751.0: 550 occurrences
# Label 1752.0: 401 occurrences
# Label 1753.0: 3796 occurrences
# Label 1754.0: 584 occurrences
# Label 1755.0: 771 occurrences
# Label 1756.0: 19 occurrences
# Label 1757.0: 601 occurrences
# Label 1758.0: 62 occurrences
# Label 1759.0: 1995 occurrences
# Label 1760.0: 1014 occurrences
# Label 1761.0: 31 occurrences
# Label 1762.0: 64 occurrences
# Label 1763.0: 2 occurrences
# Label 1764.0: 10 occurrences
# Label 1765.0: 113 occurrences
# Label 1766.0: 66 occurrences
# Label 1767.0: 12 occurrences
# Label 1768.0: 50 occurrences
# Label 1769.0: 1 occurrences
# Label 1770.0: 116 occurrences
# Label 1771.0: 12 occurrences
# Label 1772.0: 5100 occurrences
# Label 1773.0: 10043 occurrences
# Label 1774.0: 6675 occurrences
# Label 1775.0: 4239 occurrences
# Label 1776.0: 249 occurrences
# Label 1777.0: 4780 occurrences
# Label 1778.0: 817 occurrences
# Label 1779.0: 194 occurrences
# Label 1780.0: 153 occurrences
# Label 1781.0: 63 occurrences
# Label 1782.0: 72 occurrences
# Label 1783.0: 686 occurrences
# Label 1784.0: 204 occurrences
# Label 1785.0: 308 occurrences
# Label 1786.0: 245 occurrences
# Label 1787.0: 86 occurrences
# Label 1788.0: 310 occurrences
# Label 1789.0: 161 occurrences
# Label 1790.0: 16 occurrences
# Label 1791.0: 13 occurrences
# Label 1792.0: 22 occurrences
# Label 1793.0: 180 occurrences
# Label 1794.0: 97 occurrences
# Label 1795.0: 2341 occurrences
# Label 1796.0: 993 occurrences
# Label 1797.0: 58 occurrences
# Label 1798.0: 29853 occurrences
# Label 1799.0: 117 occurrences
# Label 1800.0: 126 occurrences
# Label 1801.0: 23 occurrences
# Label 1802.0: 1970 occurrences
# Label 1803.0: 956 occurrences
# Label 1804.0: 340 occurrences
# Label 1805.0: 196 occurrences
# Label 1806.0: 570 occurrences
# Label 1807.0: 1445 occurrences
# Label 1808.0: 4677 occurrences
# Label 1809.0: 106 occurrences
# Label 1810.0: 65 occurrences
# Label 1811.0: 14 occurrences
# Label 1812.0: 1941 occurrences
# Label 1813.0: 1334 occurrences
# Label 1814.0: 89 occurrences
# Label 1815.0: 432 occurrences
# Label 1816.0: 418 occurrences
# Label 1817.0: 55 occurrences
# Label 1818.0: 165 occurrences
# Label 1819.0: 38 occurrences
# Label 1820.0: 850 occurrences
# Label 1821.0: 9 occurrences
# Label 1822.0: 2722 occurrences
# Label 1823.0: 17 occurrences
# Label 1824.0: 641 occurrences
# Label 1825.0: 99 occurrences
# Label 1826.0: 106 occurrences
# Label 1827.0: 55 occurrences
# Label 1828.0: 18 occurrences
# Label 1830.0: 22 occurrences
# Label 1832.0: 46 occurrences
# Label 1833.0: 139 occurrences
# Label 1834.0: 466 occurrences
# Label 1835.0: 13 occurrences
# Label 1836.0: 71 occurrences
# Label 1837.0: 345 occurrences
# Label 1838.0: 43 occurrences
# Label 1840.0: 48 occurrences
# Label 1841.0: 126 occurrences
# Label 1842.0: 7 occurrences
# Label 1844.0: 173 occurrences
# Label 1845.0: 6 occurrences
# Label 1846.0: 1 occurrences
# Label 1847.0: 148 occurrences
# Label 1849.0: 21 occurrences
# Label 1852.0: 4 occurrences
# Label 1853.0: 30 occurrences
# Label 1854.0: 1 occurrences
# Label 1855.0: 2 occurrences
# Label 1856.0: 30 occurrences
# Label 1857.0: 140 occurrences
# Label 1858.0: 58 occurrences
# Label 1860.0: 784 occurrences
# Label 1861.0: 121 occurrences
# Label 1862.0: 158 occurrences
# Label 1863.0: 16 occurrences
# Label 1864.0: 25 occurrences
# Label 1865.0: 398 occurrences
# Label 1866.0: 603 occurrences
# Label 1867.0: 336 occurrences
# Label 1868.0: 39 occurrences
# Label 1869.0: 453 occurrences
# Label 1870.0: 49 occurrences
# Label 1871.0: 234 occurrences
# Label 1872.0: 256 occurrences
# Label 1873.0: 75 occurrences
# Label 1874.0: 169 occurrences
# Label 1875.0: 13 occurrences
# Label 1876.0: 164 occurrences
# Label 1877.0: 85 occurrences
# Label 1878.0: 36 occurrences
# Label 1879.0: 47 occurrences
# Label 1880.0: 1 occurrences
# Label 1881.0: 1 occurrences
# Label 1882.0: 357 occurrences
# Label 1883.0: 100 occurrences
# Label 1884.0: 1 occurrences
# Label 1885.0: 311 occurrences
# Label 1886.0: 379 occurrences
# Label 1887.0: 263 occurrences
# Label 1888.0: 100 occurrences
# Label 1889.0: 1407 occurrences
# Label 1890.0: 19 occurrences
# Label 1891.0: 314 occurrences
# Label 1892.0: 63 occurrences
# Label 1894.0: 39 occurrences
# Label 1895.0: 14 occurrences
# ...
# Label 2552.0: 12 occurrences
# Label 2553.0: 8 occurrences
# Label 2554.0: 922 occurrences
# Label 2555.0: 173 occurrences
# Label 2556.0: 52 occurrences
# Label 2557.0: 272 occurrences
# Label 2558.0: 4421 occurrences
# Label 2559.0: 579 occurrences
# Label 2560.0: 15 occurrences
# Label 2561.0: 25 occurrences
# Label 2563.0: 102 occurrences
# Label 2564.0: 97 occurrences
# Label 2565.0: 4 occurrences
# Label 2566.0: 9 occurrences
# Label 2567.0: 1636 occurrences
# Label 2568.0: 8 occurrences
# Label 2569.0: 368 occurrences
# Label 2570.0: 99 occurrences
# Label 2571.0: 1416 occurrences
# Label 2572.0: 46 occurrences
# Label 2573.0: 731 occurrences
# Label 2574.0: 357 occurrences
# Label 2575.0: 1287 occurrences
# Label 2576.0: 248 occurrences
# Label 2577.0: 89 occurrences
# Label 2578.0: 801 occurrences
# Label 2579.0: 61 occurrences
# Label 2581.0: 35 occurrences
# Label 2582.0: 5 occurrences
# Label 2583.0: 39 occurrences
# Label 2584.0: 67 occurrences
# Label 2585.0: 24 occurrences
# Label 2586.0: 13 occurrences
# Label 2587.0: 393 occurrences
# Label 2588.0: 237 occurrences
# Label 2589.0: 48 occurrences
# Label 2590.0: 120 occurrences
# Label 2591.0: 301 occurrences
# Label 2592.0: 132 occurrences
# Label 2593.0: 54 occurrences
# Label 2594.0: 49 occurrences
# Label 2595.0: 41 occurrences
# Label 2596.0: 206 occurrences
# Label 2597.0: 568 occurrences
# Label 2598.0: 80 occurrences
# Label 2599.0: 54344 occurrences
# Label 2600.0: 648 occurrences
# Label 2601.0: 108 occurrences
# Label 2602.0: 150 occurrences
# Label 2603.0: 292 occurrences
# Label 2604.0: 391 occurrences
# Label 2605.0: 19672 occurrences
# Label 2606.0: 6 occurrences
# Label 2607.0: 175 occurrences
# Label 2608.0: 49 occurrences
# Label 2609.0: 88 occurrences
# Label 2610.0: 64 occurrences
# Label 2611.0: 13 occurrences
# Label 2612.0: 32 occurrences
# Label 2613.0: 45 occurrences
# Label 2614.0: 111 occurrences
# Label 2615.0: 127 occurrences
# Label 2616.0: 102 occurrences
# Label 2617.0: 32 occurrences
# Label 2618.0: 54 occurrences
# Label 2619.0: 14 occurrences
# Label 2620.0: 412 occurrences
# Label 2621.0: 17 occurrences
# Label 2622.0: 73 occurrences
# Label 2623.0: 340 occurrences
# Label 2625.0: 6 occurrences
# Label 2626.0: 126 occurrences
# Label 2627.0: 1 occurrences
# Label 2628.0: 59 occurrences
# Label 2630.0: 8 occurrences
# Label 2631.0: 93 occurrences
# Label 2634.0: 297 occurrences
# Label 2635.0: 87 occurrences
# Label 2637.0: 34 occurrences
# Label 2638.0: 98 occurrences
# Label 2639.0: 177 occurrences
# Label 2640.0: 89 occurrences
# Label 2641.0: 321 occurrences
# Label 2642.0: 26 occurrences
# Label 2643.0: 14 occurrences
# Label 2644.0: 129 occurrences
# Label 2645.0: 1 occurrences
# Label 2745.0: 6 occurrences
# Label 2746.0: 17 occurrences
# Label 2747.0: 40 occurrences
# Label 2749.0: 85 occurrences
# Label 2750.0: 200 occurrences
# Label 2752.0: 9 occurrences
# Label 2753.0: 7 occurrences
# Label 2754.0: 117 occurrences
# Label 2755.0: 4 occurrences
# Label 2758.0: 10 occurrences
# Label 2759.0: 479 occurrences
# Label 2760.0: 253 occurrences
# Label 2761.0: 171 occurrences
# Label 2762.0: 487 occurrences
# Label 2763.0: 100 occurrences
# Label 2764.0: 872 occurrences
# Label 2765.0: 37 occurrences
# Label 2766.0: 2 occurrences
# Label 2767.0: 304 occurrences
# Label 2768.0: 152 occurrences
# Label 2769.0: 736 occurrences
# Label 2770.0: 193 occurrences
# Label 2771.0: 64 occurrences
# Label 2772.0: 153 occurrences
# Label 2773.0: 311 occurrences
# Label 2774.0: 3 occurrences
# Label 2775.0: 1 occurrences
# Label 2776.0: 83 occurrences
# Label 2777.0: 1801 occurrences
# Label 2778.0: 43 occurrences
# Label 2780.0: 3224 occurrences
# Label 2781.0: 165 occurrences
# Label 2782.0: 5060 occurrences
# Label 2784.0: 1237 occurrences
# Label 2785.0: 389 occurrences
# Label 2786.0: 778 occurrences
# Label 2787.0: 359 occurrences
# Label 2788.0: 62 occurrences
# Label 2789.0: 264 occurrences
# Label 2790.0: 391 occurrences
# Label 2791.0: 581 occurrences
# Label 2792.0: 156 occurrences
# Label 2793.0: 21 occurrences
# Label 2794.0: 275 occurrences
# Label 2795.0: 128 occurrences
# Label 2796.0: 161 occurrences
# Label 2797.0: 81 occurrences
# Label 2798.0: 62 occurrences
# Label 2799.0: 66 occurrences
# Label 2800.0: 25 occurrences
# Label 2801.0: 21 occurrences
# Label 2802.0: 424 occurrences
# Label 2803.0: 76 occurrences
# Label 2806.0: 776 occurrences
# Label 2807.0: 573 occurrences
# Label 2808.0: 321 occurrences
# Label 2809.0: 5 occurrences
# Label 2810.0: 58 occurrences
# Label 2811.0: 1535 occurrences
# Label 2812.0: 1975 occurrences
# Label 2813.0: 78 occurrences
# Label 2814.0: 26 occurrences
# Label 2815.0: 959 occurrences
# Label 2816.0: 120 occurrences
# Label 2817.0: 11 occurrences
# Label 2819.0: 49 occurrences
# Label 2820.0: 10 occurrences
# Label 2821.0: 36 occurrences
# Label 2822.0: 32 occurrences
# Label 2823.0: 7200 occurrences
# Label 2824.0: 28 occurrences
# Label 2827.0: 62 occurrences
# Label 2828.0: 395 occurrences
# Label 2829.0: 7 occurrences
# Label 2830.0: 13 occurrences
# Label 2831.0: 26 occurrences
# Label 2832.0: 94 occurrences
# Label 2833.0: 22 occurrences
# Label 2835.0: 7 occurrences
# Label 2836.0: 62 occurrences
# Label 2837.0: 1 occurrences
# Label 2838.0: 32 occurrences
# Label 2839.0: 144 occurrences
# Label 2840.0: 144 occurrences
# Label 2841.0: 11 occurrences
# Label 2842.0: 30 occurrences
# Label 2844.0: 78 occurrences
# Label 2847.0: 117 occurrences
# Label 2848.0: 146 occurrences
# Label 2851.0: 1 occurrences
# Label 2852.0: 9 occurrences
# Label 2853.0: 353 occurrences
# Label 2854.0: 674 occurrences
# Label 2855.0: 170 occurrences
# Label 2856.0: 784 occurrences
# Label 2857.0: 29 occurrences
# Label 2858.0: 244 occurrences
# Label 2859.0: 42 occurrences
# Label 2861.0: 557 occurrences
# Label 2862.0: 250 occurrences
# Label 2864.0: 735 occurrences
# Label 2865.0: 11 occurrences
# Label 2866.0: 86 occurrences
# Label 2867.0: 64 occurrences
# Label 2868.0: 214 occurrences
# Label 2869.0: 17 occurrences
# Label 2870.0: 2643 occurrences
# Label 2871.0: 2 occurrences
# Label 2872.0: 408 occurrences
# Label 2873.0: 6 occurrences
# Label 2875.0: 116 occurrences
# Label 2879.0: 7 occurrences
# Label 2881.0: 6 occurrences
# Label 2883.0: 1 occurrences
# Label 2886.0: 12 occurrences
# Label 2887.0: 1 occurrences
# Label 2889.0: 83 occurrences
# Label 2890.0: 26 occurrences
# Label 2893.0: 25 occurrences
# Label 2894.0: 28 occurrences
# Label 2896.0: 9 occurrences
# Label 2903.0: 51 occurrences
# Label 2904.0: 3 occurrences
# Label 2905.0: 631 occurrences
# Label 2906.0: 235 occurrences
# Label 2907.0: 14 occurrences
# Label 2909.0: 3 occurrences
# Label 2910.0: 146 occurrences
# Label 2911.0: 23 occurrences
# Label 2912.0: 150 occurrences
# Label 2913.0: 53 occurrences
# Label 2914.0: 76 occurrences
# Label 2915.0: 99 occurrences
# Label 2916.0: 103 occurrences
# Label 2917.0: 70 occurrences
# Label 2918.0: 105 occurrences
# Label 2921.0: 140 occurrences
# Label 2922.0: 193 occurrences
# Label 2923.0: 177 occurrences
# Label 2924.0: 6 occurrences
# Label 2925.0: 3 occurrences
# Label 2926.0: 1 occurrences
# Label 2927.0: 1 occurrences
# Label 2929.0: 4 occurrences
# Label 2931.0: 66 occurrences
# Label 2932.0: 381 occurrences
# Label 2933.0: 59 occurrences
# Label 2934.0: 42 occurrences
# Label 2938.0: 76 occurrences
# Label 2940.0: 1 occurrences
# Label 2941.0: 4 occurrences
# Label 2942.0: 414 occurrences
# Label 2943.0: 97 occurrences
# Label 2944.0: 232 occurrences
# Label 2945.0: 4 occurrences
# Label 2946.0: 42 occurrences
# Label 2947.0: 101 occurrences
# Label 2948.0: 105 occurrences
# Label 2949.0: 62 occurrences
# Label 2951.0: 19 occurrences
# Label 2955.0: 60 occurrences
# Label 2957.0: 1 occurrences
# Label 2958.0: 52 occurrences
# Label 2960.0: 5 occurrences
# Label 2970.0: 11 occurrences
# Label 2972.0: 24 occurrences
# Label 2973.0: 246 occurrences
# Label 2974.0: 7 occurrences
# Label 2975.0: 247 occurrences
# Label 2976.0: 1 occurrences
# Label 2977.0: 19 occurrences
# Label 2979.0: 14 occurrences
# Label 2980.0: 75 occurrences
# Label 2981.0: 7 occurrences
# Label 2982.0: 23 occurrences
# Label 2983.0: 14 occurrences
# Label 2985.0: 71 occurrences
# Label 2986.0: 31 occurrences
# Label 2988.0: 140 occurrences
# Label 2989.0: 3 occurrences
# Label 2991.0: 2 occurrences
# Label 3208.0: 153 occurrences
# Label 3209.0: 97 occurrences
# Label 3210.0: 29 occurrences
# Label 3212.0: 10 occurrences
# Label 3213.0: 5 occurrences
# Label 3214.0: 67 occurrences
# Label 3216.0: 7 occurrences

# %%
# Extract the last column (assumes the labels are in the last column)
labels = bulk_data[:, -1]

# Count the occurrences of each label
unique_labels, label_counts = np.unique(labels, return_counts=True)

# Initialize an empty list to store the sampled data
sampled_data = []

# Iterate over each label and sample data based on the label count
for label, count in zip(unique_labels, label_counts):
    label_data = bulk_data[labels == label]
    if count < 10:
        sample_size = count
    else:
        sample_size = int(0.10 * count)
    if sample_size > 0:
        sampled_indices = np.random.choice(len(label_data), size=sample_size, replace=False)
        sampled_data.append(label_data[sampled_indices])

# Concatenate the sampled data for all labels into a single array
if len(sampled_data) > 0:
    sampled_data = np.concatenate(sampled_data, axis=0)

# Check that all unique labels are present in the sampled data
assert np.all(np.isin(unique_labels, np.unique(sampled_data[:, -1])))

# Save the sampled data to a file
np.save("sampled_data.npy", sampled_data)

# %% [markdown]
# In this code, we iterate over each label and sample data based on the label count. If the count of a label is less than 10, we sample all available data points for that label. Otherwise, we sample 10% of the label count. We also check that the sample size is greater than 0 to avoid errors when sampling a label with very low count. Finally, we concatenate the sampled data for all labels, check that all unique labels are present, and save the sampled data to a file.

# %% [markdown]
# ### SPLITING THE GOLDEN_EMBEDDINGS into 80/20 train/test

# %%
# Load the entire file
golden_data = np.load('golden_embeddings.npy')

# Split the file into 80% and 20% splits
split_index = int(0.8 * len(golden_data))
train_embedding = golden_data[:split_index]
test_embedding = golden_data[split_index:]

# Save the splits as separate .npy files
np.save('train_golden_embedding.npy', train_embedding)
np.save('test_golden_embedding.npy', test_embedding)

# %%
#separating the labels from golden_embeddings to do our own prediction
test_embeddings = np.load('test_golden_embedding.npy')

# Separate the labels from the embeddings
test_labels = test_embeddings[:, -1]
test_embeddings = test_embeddings[:, :-1]

# Save the embeddings and labels as separate files
np.save('test_golden_embeddings.npy', test_embeddings)
np.save('test_golden_labels.npy', test_labels)

# %% [markdown]
# ###NN CLASSIFICATION MODEL ON BULK_SAMPLED

# %%
data = np.load('sampled_data.npy')

embeddings, labels = data[:, :-1], data[:, -1]

# Encode the labels as integers
label_encoder = LabelEncoder()
label_encoder.fit(labels)
encoded_labels = label_encoder.transform(labels)

# Convert data to PyTorch tensors
X = torch.from_numpy(embeddings).float()
y = torch.from_numpy(encoded_labels).long()

# Define the PyTorch dataset and dataloader
dataset = TensorDataset(X, y)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(200, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, len(label_encoder.classes_))
        
    def forward(self, x):
        x = torch.tanh(self.fc1(x))
        x = torch.tanh(self.fc2(x))
        x = nn.functional.softmax(self.fc3(x), dim=1)
        return x

# Initialize the neural network
net = Net()

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()

# Define the optimizer and learning rate scheduler
optimizer = optim.RMSprop(net.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.1, patience=5)

# Train the neural network
for epoch in range(10):
    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(dataloader):
        inputs, labels = data

        optimizer.zero_grad()

        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # Compute accuracy
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    # Step the scheduler
    scheduler.step(running_loss / len(dataloader))

    # Print the loss and accuracy of the current epoch
    print(f"Epoch {epoch + 1}, Loss: {running_loss / len(dataloader)} Accuracy: {100 * correct/total:.2f}%")
# Out:
# Epoch 1, Loss: 7.185574295583682 Accuracy: 75.19%
# Epoch 2, Loss: 7.063888881303127 Accuracy: 87.44%
# Epoch 3, Loss: 7.044586457635553 Accuracy: 89.37%
# Epoch 4, Loss: 7.034479275770644 Accuracy: 90.40%
# Epoch 5, Loss: 7.028433108976891 Accuracy: 91.00%
# Epoch 6, Loss: 7.024092578257135 Accuracy: 91.44%
# Epoch 7, Loss: 7.01953344418324 Accuracy: 91.90%
# Epoch 8, Loss: 7.016191233195054 Accuracy: 92.25%
# Epoch 9, Loss: 7.013811344122656 Accuracy: 92.48%
# Epoch 10, Loss: 7.0121548541061856 Accuracy: 92.64%

# %% [markdown]
# ###SAVE THE CODE

# %%
torch.save(net.state_dict(), 'pretrained_model.pth')

# %% [markdown]
# ###TRANSFER LEARNING ON WHOLE GOLDEN DATASET

# %%
# Load the data
data = np.load('golden_embeddings.npy')

# Extract the embeddings and labels
embeddings, labels = data[:, :-1], data[:, -1]

# Encode the labels as integers
label_encoder = LabelEncoder()
label_encoder.fit(labels)
encoded_labels = label_encoder.transform(labels)

# Convert data to PyTorch tensors
X = torch.from_numpy(embeddings).float()
y = torch.from_numpy(encoded_labels).long()

# Define the PyTorch dataset and dataloader
dataset = TensorDataset(X, y)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

class NewNet(nn.Module):
    def __init__(self, pretrained_model, n_classes):
        super(NewNet, self).__init__()

        # Define the pretrained layers
        self.fc1 = nn.Linear(200, 256)
        self.fc2 = nn.Linear(256, 128)

        # Define the new layers
        self.fc3 = nn.Linear(128, n_classes)
#fc1.weight', 'fc1.bias', 'fc2.weight', 'fc2.bias', 'fc3.weight', 'fc3.bias'
        # Load the pretrained weights
        self.fc1.weight.data = pretrained_model['fc1.weight']
        self.fc1.bias.data = pretrained_model['fc1.bias']
        self.fc2.weight.data = pretrained_model['fc2.weight']
        self.fc2.bias.data = pretrained_model['fc2.bias']
        self.fc3.weight.data = pretrained_model['fc3.weight']
        self.fc3.bias.data = pretrained_model['fc3.bias']

    def forward(self, x):
        x = torch.tanh(self.fc1(x))
        x = torch.tanh(self.fc2(x))
        x = nn.functional.softmax(self.fc3(x), dim=1)
        return x


# Load the pretrained model
pretrained_state_dict = torch.load('pretrained_model.pth')

# Get the number of classes
n_classes = len(label_encoder.classes_)

# Initialize the new network
net = NewNet(pretrained_state_dict, n_classes)

# Freeze the parameters of the pretrained layers
for param in net.fc1.parameters():
    param.requires_grad = False
for param in net.fc2.parameters():
    param.requires_grad = False

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.RMSprop(net.fc3.parameters(), lr=0.001)

# Define the learning rate scheduler
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.1, patience=5)

# Train the neural network
for epoch in range(10):
    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(dataloader):
        inputs, labels = data

        optimizer.zero_grad()

        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # Compute accuracy
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    # Step the scheduler
    scheduler.step(running_loss / len(dataloader))

    # Print the loss and accuracy of the current epoch
    print(f"Epoch {epoch + 1}, Loss: {running_loss / len(dataloader)} Accuracy: {100 * correct/total:.2f}%")
# Out:
# Epoch 1, Loss: 7.4528805486667205 Accuracy: 49.05%
# Epoch 2, Loss: 7.2685827686678355 Accuracy: 67.57%
# Epoch 3, Loss: 7.2474426427194265 Accuracy: 69.60%
# Epoch 4, Loss: 7.23858619379453 Accuracy: 70.45%
# Epoch 5, Loss: 7.232782872283352 Accuracy: 71.03%
# Epoch 6, Loss: 7.228137534583305 Accuracy: 71.44%
# Epoch 7, Loss: 7.224778463083505 Accuracy: 71.79%
# Epoch 8, Loss: 7.222048855773419 Accuracy: 72.03%
# Epoch 9, Loss: 7.219395687757672 Accuracy: 72.31%
# Epoch 10, Loss: 7.217353874454582 Accuracy: 72.53%

# %% [markdown]
# ### PREDICTING LABLES OF golden_dataset_without_labels

# %%
# Load the new embeddings
new_embeddings = np.load('golden_dataset_without_labels_part1.npy')

# Convert data to PyTorch tensor
new_features = torch.from_numpy(new_embeddings).float()

# Predict labels for the new embeddings
net.eval()
with torch.no_grad():
    outputs = net(new_features)
    _, predicted = torch.max(outputs.data, 1)

# Decode the predicted labels using the label encoder
predicted_labels_part1 = label_encoder.inverse_transform(predicted.numpy())

# %%
# Load the new embeddings
new_embeddings = np.load('golden_dataset_without_labels_part2.npy')

# Convert data to PyTorch tensor
new_features = torch.from_numpy(new_embeddings).float()

# Predict labels for the new embeddings
net.eval()
with torch.no_grad():
    outputs = net(new_features)
    _, predicted = torch.max(outputs.data, 1)

# Decode the predicted labels using the label encoder
predicted_labels_part2 = label_encoder.inverse_transform(predicted.numpy())

# %%
predicted_labels=np.concatenate((predicted_labels_part1, predicted_labels_part2), axis=0)

# %%
# Save the numpy array as a .npy file
np.save('predicted_labels.npy', predicted_labels)

# %%
# Load the numpy array from the .npy file
loaded_labels = np.load('predicted_labels.npy')

# Print the loaded numpy array
print(loaded_labels)

# %%
print(predicted_labels_part1)
print(predicted_labels_part2)
print(predicted_labels)

# %% [markdown]
# #### Divided the golden_dataset_without_labels.npy files into 2 parts beacuse it was too huge to process it at once. Then concatenated the PREDICTED LABELS of divided parts.

# %% [markdown]
# # TESTING

# %% [markdown]
# ###TRANSFER LEARNING ON 80% TRAIN AND 20% TEST GOLDEN DATASET

# %%
# # Load the data
# data = np.load('golden_embeddings.npy')

# # Extract the embeddings and labels
# embeddings, labels = data[:, :-1], data[:, -1]

# # Encode the labels as integers
# label_encoder = LabelEncoder()
# label_encoder.fit(labels)
# encoded_labels = label_encoder.transform(labels)

# # Split the data into train and test sets
# X_train, X_test, y_train, y_test = train_test_split(embeddings, encoded_labels, test_size=0.2, random_state=42)

# # Convert data to PyTorch tensors
# X_train = torch.from_numpy(X_train).float()
# y_train = torch.from_numpy(y_train).long()
# X_test = torch.from_numpy(X_test).float()
# y_test = torch.from_numpy(y_test).long()

# # Define the PyTorch dataset and dataloader for train set
# train_dataset = TensorDataset(X_train, y_train)
# train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# # Define the PyTorch dataset and dataloader for test set
# test_dataset = TensorDataset(X_test, y_test)
# test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# class NewNet(nn.Module):
#     def __init__(self, pretrained_model, n_classes):
#         super(NewNet, self).__init__()

#         # Define the pretrained layers
#         self.fc1 = nn.Linear(200, 256)
#         self.fc2 = nn.Linear(256, 128)

#         # Define the new layers
#         self.fc3 = nn.Linear(128, n_classes)

#         # Load the pretrained weights
#         self.fc1.weight.data = pretrained_model['fc1.weight']
#         self.fc1.bias.data = pretrained_model['fc1.bias']
#         self.fc2.weight.data = pretrained_model['fc2.weight']
#         self.fc2.bias.data = pretrained_model['fc2.bias']
#         self.fc3.weight.data = pretrained_model['fc3.weight']
#         self.fc3.bias.data = pretrained_model['fc3.bias']

#     def forward(self, x):
#         x = torch.tanh(self.fc1(x))
#         x = torch.tanh(self.fc2(x))
#         x = nn.functional.softmax(self.fc3(x), dim=1)
#         return x


# # Load the pretrained model
# pretrained_state_dict = torch.load('pretrained_model.pth')

# # Get the number of classes
# n_classes = len(label_encoder.classes_)

# # Initialize the new network
# net = NewNet(pretrained_state_dict, n_classes)

# # Freeze the parameters of the pretrained layers
# for param in net.fc1.parameters():
#     param.requires_grad = False
# for param in net.fc2.parameters():
#     param.requires_grad = False

# # Define the loss function and optimizer
# criterion = nn.CrossEntropyLoss()
# optimizer = optim.RMSprop(net.fc3.parameters(), lr=0.001)

# # Define the learning rate scheduler
# scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.1, patience=5)

# # Train the neural network
# for epoch in range(10):
#     train_loss = 0.0
#     train_correct = 0
#     train_total = 0
#     for i, data in enumerate(train_dataloader):
#         inputs, labels = data
#         optimizer.zero_grad()

#         outputs = net(inputs)
#         loss = criterion(outputs, labels)
#         loss.backward()
#         optimizer.step()

#         running_loss += loss.item()

#         # Compute accuracy
#         _, predicted = torch.max(outputs.data, 1)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()

# # Step the scheduler
# #scheduler.step(running_loss / len(train_loader))
# scheduler.step(running_loss / len(dataloader))

# # Print the loss and accuracy of the current epoch
# print(f"Epoch {epoch + 1}, Loss: {running_loss / len(train_dataloader)} Accuracy: {100 * correct/total:.2f}%")

# # Evaluate the model on the test set
# net.eval()
# test_loss = 0.0
# test_correct = 0
# test_total = 0
# with torch.no_grad():
#     for i, data in enumerate(test_dataloader):
#         inputs, labels = data

#         outputs = net(inputs)
#         loss = criterion(outputs, labels)

#         test_loss += loss.item()

#         # Compute accuracy
#         _, predicted = torch.max(outputs.data, 1)
#         test_total += labels.size(0)
#         test_correct += (predicted == labels).sum().item()

# # Print the test loss and accuracy of the current epoch
# print(f"Test Loss: {test_loss / len(test_dataloader)} Test Accuracy: {100 * test_correct/test_total:.2f}%")

# %% [markdown]
# ###TRANSFER LEARNING ON 80% TRAIN GOLDEN DATASET

# %%
# # Load the data
# data = np.load('train_golden_embedding.npy')

# # Extract the embeddings and labels
# embeddings, labels = data[:, :-1], data[:, -1]

# # Encode the labels as integers
# label_encoder = LabelEncoder()
# label_encoder.fit(labels)
# encoded_labels = label_encoder.transform(labels)

# # Convert data to PyTorch tensors
# X = torch.from_numpy(embeddings).float()
# y = torch.from_numpy(encoded_labels).long()

# # Define the PyTorch dataset and dataloader
# dataset = TensorDataset(X, y)
# dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# class NewNet(nn.Module):
#     def __init__(self, pretrained_model, n_classes):
#         super(NewNet, self).__init__()

#         # Define the pretrained layers
#         self.fc1 = nn.Linear(200, 256)
#         self.fc2 = nn.Linear(256, 128)

#         # Define the new layers
#         self.fc3 = nn.Linear(128, n_classes)
# #fc1.weight', 'fc1.bias', 'fc2.weight', 'fc2.bias', 'fc3.weight', 'fc3.bias'
#         # Load the pretrained weights
#         self.fc1.weight.data = pretrained_model['fc1.weight']
#         self.fc1.bias.data = pretrained_model['fc1.bias']
#         self.fc2.weight.data = pretrained_model['fc2.weight']
#         self.fc2.bias.data = pretrained_model['fc2.bias']
#         self.fc3.weight.data = pretrained_model['fc3.weight']
#         self.fc3.bias.data = pretrained_model['fc3.bias']

#     def forward(self, x):
#         x = torch.tanh(self.fc1(x))
#         x = torch.tanh(self.fc2(x))
#         x = nn.functional.softmax(self.fc3(x), dim=1)
#         return x


# # Load the pretrained model
# pretrained_state_dict = torch.load('pretrained_model.pth')

# # Get the number of classes
# n_classes = len(label_encoder.classes_)

# # Initialize the new network
# net = NewNet(pretrained_state_dict, n_classes)

# # Freeze the parameters of the pretrained layers
# for param in net.fc1.parameters():
#     param.requires_grad = False
# for param in net.fc2.parameters():
#     param.requires_grad = False

# # Define the loss function and optimizer
# criterion = nn.CrossEntropyLoss()
# optimizer = optim.RMSprop(net.fc3.parameters(), lr=0.001)

# # Define the learning rate scheduler
# scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.1, patience=5)

# # Train the neural network
# for epoch in range(10):
#     running_loss = 0.0
#     correct = 0
#     total = 0
#     for i, data in enumerate(dataloader):
#         inputs, labels = data

#         optimizer.zero_grad()

#         outputs = net(inputs)
#         loss = criterion(outputs, labels)
#         loss.backward()
#         optimizer.step()

#         running_loss += loss.item()

#         # Compute accuracy
#         _, predicted = torch.max(outputs.data, 1)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()

#     # Step the scheduler
#     scheduler.step(running_loss / len(dataloader))

#     # Print the loss and accuracy of the current epoch
#     print(f"Epoch {epoch + 1}, Loss: {running_loss / len(dataloader)} Accuracy: {100 * correct/total:.2f}%")

# %% [markdown]
# ###PREDICTING LABELS ON REMAINING 20% GOLDEN DATASET

# %%
# # Load the new embeddings
# new_embeddings = np.load('test_golden_embedding.npy')

# # Convert data to PyTorch tensor
# new_features = torch.from_numpy(new_embeddings).float()

# # Predict labels for the new embeddings
# net.eval()
# with torch.no_grad():
#     outputs = net(new_features)
#     _, predicted = torch.max(outputs.data, 1)

# # Decode the predicted labels using the label encoder
# predicted_labels = label_encoder.inverse_transform(predicted.numpy())

# %%
# actual_labels=np.load("test_golden_labels.npy")

# %% [markdown]
# ### ACTUAL VS PREDICTED LABELS

# %%
# total_actual_labels_count = len(actual_labels)
# total_predicted_labels_count = len(predicted_labels)
# matched_labels_count = np.sum(predicted_labels == actual_labels)
# mismatched_labels_count = np.sum(predicted_labels != actual_labels)

# matched_labels_percent = matched_labels_count / total_actual_labels_count * 100

# print(f"Total actual label count: {total_actual_labels_count}")
# print(f"Total predicted label count: {total_predicted_labels_count}")
# print(f"Matched label count: {matched_labels_count}")
# print(f"Mismatched label count: {mismatched_labels_count}")
# print(f"Matched label percentage: {matched_labels_percent:.2f}%")
